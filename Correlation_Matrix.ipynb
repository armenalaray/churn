# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

churn_data = pd.read_csv('scores.csv', index_col=[0,1])

# %%
churn_data = churn_data.reindex(sorted(churn_data.columns), axis=1)

# %%
corr_df = churn_data.corr()

corr_df
#corr_df.to_csv('correlation_matrix.csv')
# Out:
#                      account_tenure  adview_per_month  dislike_per_month  \
# account_tenure             1.000000          0.061760           0.060071
# adview_per_month           0.061760          1.000000           0.450231
# dislike_per_month          0.060071          0.450231           1.000000
# is_churn                  -0.023082         -0.035216          -0.027846
# like_per_month             0.061766          0.671854           0.455247
# message_per_month          0.055552          0.134186           0.151363
# newfriend_per_month        0.055892          0.534020           0.369960
# post_per_month             0.066351          0.663394           0.436487
# reply_per_month            0.045859          0.091390           0.117070
# unfriend_per_month         0.027569          0.002303           0.001698
#
#                      is_churn  like_per_month  message_per_month  \
# account_tenure      -0.023082        0.061766           0.055552
# adview_per_month    -0.035216        0.671854           0.134186
# dislike_per_month   -0.027846        0.455247           0.151363
# is_churn             1.000000       -0.058996          -0.092034
# like_per_month      -0.058996        1.000000           0.110282
# message_per_month   -0.092034        0.110282           1.000000
# newfriend_per_month -0.031964        0.540212           0.080746
# post_per_month      -0.059814        0.664195           0.104917
# reply_per_month     -0.078214        0.069780           0.881624
# unfriend_per_month   0.027445       -0.003704           0.002029
#
#                      newfriend_per_month  post_per_month  reply_per_month  \
# account_tenure                  0.055892        0.066351         0.045859
# adview_per_month                0.534020        0.663394         0.091390
# dislike_per_month               0.369960        0.436487         0.117070
# is_churn                       -0.031964       -0.059814        -0.078214
# like_per_month                  0.540212        0.664195         0.069780
# message_per_month               0.080746        0.104917         0.881624
# newfriend_per_month             1.000000        0.529523         0.043871
# post_per_month                  0.529523        1.000000         0.066494
# reply_per_month                 0.043871        0.066494         1.000000
# unfriend_per_month              0.001383        0.001577         0.002733
#
#                      unfriend_per_month
# account_tenure                 0.027569
# adview_per_month               0.002303
# dislike_per_month              0.001698
# is_churn                       0.027445
# like_per_month                -0.003704
# message_per_month              0.002029
# newfriend_per_month            0.001383
# post_per_month                 0.001577
# reply_per_month                0.002733
# unfriend_per_month             1.000000

# %%
plt.imshow(corr_df, cmap='bwr')
plt.colorbar(label='Value')
plt.title('Correlation Matrix')
plt.savefig('Correlation_Matrix.png')

# %%
loading matrix
# Out:
#   Cell In[39], line 1
#     loading matrix
#             ^
# SyntaxError: invalid syntax
